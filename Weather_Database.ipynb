# %%
# Import Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from citipy import citipy

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create 2000 sets of random latitutde and logitude combinations.

lats = np.random.uniform(-90.000,90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lats_lngs = zip(lats, lngs)
lats_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lats_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 751

# %%
# Import the time library and the datetime module from the datetime library
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Begginning Data Retrieval    ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1


# Loop through all the cities in our list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        #Parse out the needed data
        city_country = city_weather['sys']['country']
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        current_weather = city_weather['weather'][0]['description']
        # Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather['dt']).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": current_weather})
        
 #If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
    
# Indicate that the data loading is complete.
print("------------------------------")
print("Data Retrieval Complete       ")
print("------------------------------")
# Out:
# Begginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | saskylakh
# Processing Record 2 of Set 1 | el vigia
# Processing Record 3 of Set 1 | avarua
# Processing Record 4 of Set 1 | ushtobe
# Processing Record 5 of Set 1 | bluff
# Processing Record 6 of Set 1 | ardakan
# Processing Record 7 of Set 1 | tautira
# Processing Record 8 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 9 of Set 1 | kintampo
# Processing Record 10 of Set 1 | alta floresta
# Processing Record 11 of Set 1 | novopavlovka
# Processing Record 12 of Set 1 | hermanus
# Processing Record 13 of Set 1 | nikolskoye
# Processing Record 14 of Set 1 | saint-philippe
# Processing Record 15 of Set 1 | cape town
# Processing Record 16 of Set 1 | katsuura
# Processing Record 17 of Set 1 | diamantina
# Processing Record 18 of Set 1 | hobart
# Processing Record 19 of Set 1 | yellowknife
# Processing Record 20 of Set 1 | rikitea
# Processing Record 21 of Set 1 | gubkinskiy
# Processing Record 22 of Set 1 | isangel
# Processing Record 23 of Set 1 | albany
# Processing Record 24 of Set 1 | faya
# Processing Record 25 of Set 1 | port lincoln
# Processing Record 26 of Set 1 | paamiut
# Processing Record 27 of Set 1 | mahebourg
# Processing Record 28 of Set 1 | hilo
# Processing Record 29 of Set 1 | pemangkat
# Processing Record 30 of Set 1 | lima
# Processing Record 31 of Set 1 | norman wells
# Processing Record 32 of Set 1 | vaini
# Processing Record 33 of Set 1 | mountain home
# Processing Record 34 of Set 1 | atuona
# Processing Record 35 of Set 1 | hamilton
# Processing Record 36 of Set 1 | ko samui
# Processing Record 37 of Set 1 | pudozh
# Processing Record 38 of Set 1 | coos bay
# Processing Record 39 of Set 1 | dunmore town
# Processing Record 40 of Set 1 | hithadhoo
# Processing Record 41 of Set 1 | butaritari
# Processing Record 42 of Set 1 | kapaa
# Processing Record 43 of Set 1 | san angelo
# Processing Record 44 of Set 1 | busselton
# Processing Record 45 of Set 1 | kodiak
# Processing Record 46 of Set 1 | carnarvon
# Processing Record 47 of Set 1 | casino
# Processing Record 48 of Set 1 | mahajanga
# Processing Record 49 of Set 1 | druzhba
# Processing Record 50 of Set 1 | chulym
# Processing Record 1 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 2 of Set 2 | mehamn
# Processing Record 3 of Set 2 | mar del plata
# Processing Record 4 of Set 2 | codrington
# Processing Record 5 of Set 2 | binzhou
# Processing Record 6 of Set 2 | ushuaia
# Processing Record 7 of Set 2 | punta arenas
# Processing Record 8 of Set 2 | tianpeng
# Processing Record 9 of Set 2 | arroyo
# Processing Record 10 of Set 2 | khatanga
# Processing Record 11 of Set 2 | macia
# Processing Record 12 of Set 2 | samarai
# Processing Record 13 of Set 2 | havre-saint-pierre
# Processing Record 14 of Set 2 | san cristobal
# Processing Record 15 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 16 of Set 2 | kawalu
# Processing Record 17 of Set 2 | santiago del estero
# Processing Record 18 of Set 2 | talakan
# Processing Record 19 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 20 of Set 2 | oum hadjer
# Processing Record 21 of Set 2 | belmonte
# Processing Record 22 of Set 2 | ilulissat
# Processing Record 23 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 24 of Set 2 | srednekolymsk
# Processing Record 25 of Set 2 | poya
# Processing Record 26 of Set 2 | tomatlan
# Processing Record 27 of Set 2 | akcaabat
# Processing Record 28 of Set 2 | port macquarie
# Processing Record 29 of Set 2 | mocuba
# Processing Record 30 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 31 of Set 2 | jalu
# Processing Record 32 of Set 2 | bonthe
# Processing Record 33 of Set 2 | barrow
# Processing Record 34 of Set 2 | zhezkazgan
# Processing Record 35 of Set 2 | abha
# Processing Record 36 of Set 2 | chuy
# Processing Record 37 of Set 2 | severo-kurilsk
# Processing Record 38 of Set 2 | kavieng
# Processing Record 39 of Set 2 | atambua
# Processing Record 40 of Set 2 | karsava
# Processing Record 41 of Set 2 | kaitangata
# Processing Record 42 of Set 2 | tuktoyaktuk
# Processing Record 43 of Set 2 | coquimbo
# Processing Record 44 of Set 2 | richards bay
# Processing Record 45 of Set 2 | lavrentiya
# Processing Record 46 of Set 2 | burnie
# Processing Record 47 of Set 2 | cabedelo
# Processing Record 48 of Set 2 | zhigansk
# Processing Record 49 of Set 2 | thompson
# Processing Record 50 of Set 2 | vardo
# Processing Record 1 of Set 3 | souillac
# Processing Record 2 of Set 3 | bredasdorp
# Processing Record 3 of Set 3 | la palma
# Processing Record 4 of Set 3 | provideniya
# Processing Record 5 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 6 of Set 3 | arraial do cabo
# Processing Record 7 of Set 3 | blatnica
# Processing Record 8 of Set 3 | namatanai
# Processing Record 9 of Set 3 | mataura
# Processing Record 10 of Set 3 | talnakh
# Processing Record 11 of Set 3 | puerto escondido
# Processing Record 12 of Set 3 | lebu
# Processing Record 13 of Set 3 | komsomolskiy
# Processing Record 14 of Set 3 | lompoc
# Processing Record 15 of Set 3 | port alfred
# Processing Record 16 of Set 3 | cabo san lucas
# Processing Record 17 of Set 3 | bengkulu
# Processing Record 18 of Set 3 | hervey bay
# Processing Record 19 of Set 3 | sembe
# Processing Record 20 of Set 3 | roberval
# Processing Record 21 of Set 3 | adamovka
# Processing Record 22 of Set 3 | laguna
# Processing Record 23 of Set 3 | jamestown
# Processing Record 24 of Set 3 | mezen
# Processing Record 25 of Set 3 | qaanaaq
# Processing Record 26 of Set 3 | quatre cocos
# Processing Record 27 of Set 3 | nanortalik
# Processing Record 28 of Set 3 | umm kaddadah
# Processing Record 29 of Set 3 | gbarnga
# Processing Record 30 of Set 3 | maloy
# Processing Record 31 of Set 3 | geraldton
# Processing Record 32 of Set 3 | banjar
# Processing Record 33 of Set 3 | lao cai
# Processing Record 34 of Set 3 | dongkan
# Processing Record 35 of Set 3 | pamanukan
# Processing Record 36 of Set 3 | bandarbeyla
# Processing Record 37 of Set 3 | ponta do sol
# Processing Record 38 of Set 3 | castro
# Processing Record 39 of Set 3 | faanui
# Processing Record 40 of Set 3 | guerrero negro
# Processing Record 41 of Set 3 | matay
# Processing Record 42 of Set 3 | el alto
# Processing Record 43 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 44 of Set 3 | ostrovnoy
# Processing Record 45 of Set 3 | turukhansk
# Processing Record 46 of Set 3 | krasnovishersk
# Processing Record 47 of Set 3 | moron
# Processing Record 48 of Set 3 | lagoa
# Processing Record 49 of Set 3 | dikson
# Processing Record 50 of Set 3 | port elizabeth
# Processing Record 1 of Set 4 | mana
# Processing Record 2 of Set 4 | muravlenko
# Processing Record 3 of Set 4 | te anau
# Processing Record 4 of Set 4 | dingle
# Processing Record 5 of Set 4 | portland
# Processing Record 6 of Set 4 | cayenne
# Processing Record 7 of Set 4 | fujin
# Processing Record 8 of Set 4 | upata
# Processing Record 9 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 10 of Set 4 | kulob
# Processing Record 11 of Set 4 | spassk-ryazanskiy
# Processing Record 12 of Set 4 | grindavik
# Processing Record 13 of Set 4 | topeka
# Processing Record 14 of Set 4 | tuatapere
# Processing Record 15 of Set 4 | naze
# Processing Record 16 of Set 4 | victoria
# Processing Record 17 of Set 4 | pisco
# Processing Record 18 of Set 4 | quelimane
# Processing Record 19 of Set 4 | yulara
# Processing Record 20 of Set 4 | inongo
# Processing Record 21 of Set 4 | labytnangi
# Processing Record 22 of Set 4 | walvis bay
# Processing Record 23 of Set 4 | namibe
# Processing Record 24 of Set 4 | cockburn town
# Processing Record 25 of Set 4 | kousseri
# Processing Record 26 of Set 4 | salalah
# Processing Record 27 of Set 4 | saint-augustin
# Processing Record 28 of Set 4 | kuytun
# Processing Record 29 of Set 4 | wanaka
# Processing Record 30 of Set 4 | restrepo
# Processing Record 31 of Set 4 | chokurdakh
# Processing Record 32 of Set 4 | margate
# Processing Record 33 of Set 4 | palmer
# Processing Record 34 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 35 of Set 4 | cherskiy
# Processing Record 36 of Set 4 | georgetown
# Processing Record 37 of Set 4 | college
# Processing Record 38 of Set 4 | taoudenni
# Processing Record 39 of Set 4 | tual
# Processing Record 40 of Set 4 | mount isa
# Processing Record 41 of Set 4 | torbay
# Processing Record 42 of Set 4 | bardiyah
# Processing Record 43 of Set 4 | east london
# Processing Record 44 of Set 4 | leh
# Processing Record 45 of Set 4 | qaqortoq
# Processing Record 46 of Set 4 | monte patria
# Processing Record 47 of Set 4 | farah
# Processing Record 48 of Set 4 | san patricio
# Processing Record 49 of Set 4 | bacolod
# Processing Record 50 of Set 4 | krasnyy kholm
# Processing Record 1 of Set 5 | port hedland
# Processing Record 2 of Set 5 | madhugiri
# Processing Record 3 of Set 5 | sorvag
# City not found. Skipping...
# Processing Record 4 of Set 5 | leningradskiy
# Processing Record 5 of Set 5 | port hardy
# Processing Record 6 of Set 5 | bethel
# Processing Record 7 of Set 5 | haines junction
# Processing Record 8 of Set 5 | feltre
# Processing Record 9 of Set 5 | tiksi
# Processing Record 10 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 11 of Set 5 | gomel
# Processing Record 12 of Set 5 | hasaki
# Processing Record 13 of Set 5 | sydney
# Processing Record 14 of Set 5 | puerto ayora
# Processing Record 15 of Set 5 | nyrob
# Processing Record 16 of Set 5 | rimouski
# Processing Record 17 of Set 5 | puerto colombia
# Processing Record 18 of Set 5 | karratha
# Processing Record 19 of Set 5 | menongue
# Processing Record 20 of Set 5 | awjilah
# Processing Record 21 of Set 5 | caravelas
# Processing Record 22 of Set 5 | abu kamal
# Processing Record 23 of Set 5 | uruzgan
# Processing Record 24 of Set 5 | new norfolk
# Processing Record 25 of Set 5 | mataram
# Processing Record 26 of Set 5 | kongolo
# Processing Record 27 of Set 5 | baghdad
# Processing Record 28 of Set 5 | christchurch
# Processing Record 29 of Set 5 | odweyne
# Processing Record 30 of Set 5 | juneau
# Processing Record 31 of Set 5 | hihifo
# City not found. Skipping...
# Processing Record 32 of Set 5 | abnub
# Processing Record 33 of Set 5 | honiara
# Processing Record 34 of Set 5 | zhuhai
# Processing Record 35 of Set 5 | malinovoye ozero
# Processing Record 36 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 37 of Set 5 | coihaique
# Processing Record 38 of Set 5 | lorengau
# Processing Record 39 of Set 5 | araouane
# Processing Record 40 of Set 5 | shagamu
# Processing Record 41 of Set 5 | vilhena
# Processing Record 42 of Set 5 | fort nelson
# Processing Record 43 of Set 5 | fallon
# Processing Record 44 of Set 5 | syasstroy
# Processing Record 45 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 46 of Set 5 | upington
# Processing Record 47 of Set 5 | beringovskiy
# Processing Record 48 of Set 5 | tutoia
# Processing Record 49 of Set 5 | bethanien
# Processing Record 50 of Set 5 | marawi
# Processing Record 1 of Set 6 | longyearbyen
# Processing Record 2 of Set 6 | airai
# Processing Record 3 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 4 of Set 6 | kontagora
# Processing Record 5 of Set 6 | kyra
# Processing Record 6 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 7 of Set 6 | real
# Processing Record 8 of Set 6 | nguiu
# City not found. Skipping...
# Processing Record 9 of Set 6 | puerto cabezas
# Processing Record 10 of Set 6 | puerto pinasco
# City not found. Skipping...
# Processing Record 11 of Set 6 | yangjiang
# Processing Record 12 of Set 6 | seydi
# Processing Record 13 of Set 6 | kisesa
# Processing Record 14 of Set 6 | poum
# Processing Record 15 of Set 6 | batemans bay
# Processing Record 16 of Set 6 | ribeira grande
# Processing Record 17 of Set 6 | yacuiba
# Processing Record 18 of Set 6 | yakeshi
# Processing Record 19 of Set 6 | gore
# Processing Record 20 of Set 6 | orlik
# Processing Record 21 of Set 6 | iwanai
# Processing Record 22 of Set 6 | broome
# Processing Record 23 of Set 6 | new albany
# Processing Record 24 of Set 6 | warmbad
# Processing Record 25 of Set 6 | tarrafal
# Processing Record 26 of Set 6 | sulina
# Processing Record 27 of Set 6 | vao
# Processing Record 28 of Set 6 | cidreira
# Processing Record 29 of Set 6 | antalaha
# Processing Record 30 of Set 6 | aklavik
# Processing Record 31 of Set 6 | madang
# Processing Record 32 of Set 6 | capiibary
# Processing Record 33 of Set 6 | zyryanka
# Processing Record 34 of Set 6 | nuevo imperial
# Processing Record 35 of Set 6 | praxedis guerrero
# Processing Record 36 of Set 6 | pangnirtung
# Processing Record 37 of Set 6 | hofn
# Processing Record 38 of Set 6 | contamana
# Processing Record 39 of Set 6 | pacific grove
# Processing Record 40 of Set 6 | zakamensk
# Processing Record 41 of Set 6 | bambous virieux
# Processing Record 42 of Set 6 | formoso do araguaia
# City not found. Skipping...
# Processing Record 43 of Set 6 | bac lieu
# Processing Record 44 of Set 6 | fontanka
# Processing Record 45 of Set 6 | kenai
# Processing Record 46 of Set 6 | leua
# Processing Record 47 of Set 6 | pauini
# Processing Record 48 of Set 6 | shenjiamen
# Processing Record 49 of Set 6 | wajir
# Processing Record 50 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 1 of Set 7 | klaksvik
# Processing Record 2 of Set 7 | murgab
# Processing Record 3 of Set 7 | berlevag
# Processing Record 4 of Set 7 | vanimo
# Processing Record 5 of Set 7 | tezu
# Processing Record 6 of Set 7 | eureka
# Processing Record 7 of Set 7 | tabas
# Processing Record 8 of Set 7 | lata
# Processing Record 9 of Set 7 | nemuro
# Processing Record 10 of Set 7 | narsaq
# Processing Record 11 of Set 7 | kidal
# Processing Record 12 of Set 7 | safwah
# City not found. Skipping...
# Processing Record 13 of Set 7 | awbari
# Processing Record 14 of Set 7 | san juan
# Processing Record 15 of Set 7 | dondo
# Processing Record 16 of Set 7 | avera
# Processing Record 17 of Set 7 | krasnoselkup
# Processing Record 18 of Set 7 | praia da vitoria
# Processing Record 19 of Set 7 | lethem
# Processing Record 20 of Set 7 | hastings
# Processing Record 21 of Set 7 | axim
# Processing Record 22 of Set 7 | juba
# Processing Record 23 of Set 7 | viramgam
# Processing Record 24 of Set 7 | sheltozero
# Processing Record 25 of Set 7 | coahuayana
# Processing Record 26 of Set 7 | kalmunai
# Processing Record 27 of Set 7 | port pirie
# Processing Record 28 of Set 7 | hwange
# Processing Record 29 of Set 7 | bathsheba
# Processing Record 30 of Set 7 | yamethin
# Processing Record 31 of Set 7 | ostuacan
# Processing Record 32 of Set 7 | miracatu
# Processing Record 33 of Set 7 | nioro
# Processing Record 34 of Set 7 | north bend
# Processing Record 35 of Set 7 | burla
# Processing Record 36 of Set 7 | narasannapeta
# Processing Record 37 of Set 7 | khani
# Processing Record 38 of Set 7 | constantine
# Processing Record 39 of Set 7 | kruisfontein
# Processing Record 40 of Set 7 | asau
# Processing Record 41 of Set 7 | henties bay
# Processing Record 42 of Set 7 | miaga
# Processing Record 43 of Set 7 | roald
# Processing Record 44 of Set 7 | rodino
# Processing Record 45 of Set 7 | makung
# City not found. Skipping...
# Processing Record 46 of Set 7 | necochea
# Processing Record 47 of Set 7 | chernihiv
# Processing Record 48 of Set 7 | balkanabat
# Processing Record 49 of Set 7 | lazaro cardenas
# Processing Record 50 of Set 7 | ranong
# Processing Record 1 of Set 8 | washington
# Processing Record 2 of Set 8 | sorong
# Processing Record 3 of Set 8 | fairbanks
# Processing Record 4 of Set 8 | jiamusi
# Processing Record 5 of Set 8 | mangan
# Processing Record 6 of Set 8 | sharkan
# Processing Record 7 of Set 8 | arman
# Processing Record 8 of Set 8 | penzance
# Processing Record 9 of Set 8 | araguacu
# Processing Record 10 of Set 8 | russell
# Processing Record 11 of Set 8 | chakia
# Processing Record 12 of Set 8 | skibbereen
# Processing Record 13 of Set 8 | nuqui
# Processing Record 14 of Set 8 | padilla
# Processing Record 15 of Set 8 | upernavik
# Processing Record 16 of Set 8 | talitsy
# Processing Record 17 of Set 8 | okhotsk
# Processing Record 18 of Set 8 | riyadh
# Processing Record 19 of Set 8 | yumen
# Processing Record 20 of Set 8 | listica
# City not found. Skipping...
# Processing Record 21 of Set 8 | chara
# Processing Record 22 of Set 8 | eldikan
# City not found. Skipping...
# Processing Record 23 of Set 8 | little rock
# Processing Record 24 of Set 8 | tessalit
# Processing Record 25 of Set 8 | inhambane
# Processing Record 26 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 27 of Set 8 | aljezur
# Processing Record 28 of Set 8 | bambanglipuro
# Processing Record 29 of Set 8 | manaus
# Processing Record 30 of Set 8 | saldanha
# Processing Record 31 of Set 8 | padang
# Processing Record 32 of Set 8 | evensk
# Processing Record 33 of Set 8 | yeppoon
# Processing Record 34 of Set 8 | tubmanburg
# Processing Record 35 of Set 8 | bubaque
# Processing Record 36 of Set 8 | bud
# Processing Record 37 of Set 8 | hami
# Processing Record 38 of Set 8 | ilhabela
# Processing Record 39 of Set 8 | togur
# Processing Record 40 of Set 8 | arys
# Processing Record 41 of Set 8 | yaan
# Processing Record 42 of Set 8 | ahipara
# Processing Record 43 of Set 8 | bayir
# Processing Record 44 of Set 8 | itarema
# Processing Record 45 of Set 8 | yar-sale
# Processing Record 46 of Set 8 | bandarban
# Processing Record 47 of Set 8 | suntar
# Processing Record 48 of Set 8 | vung tau
# Processing Record 49 of Set 8 | prieska
# Processing Record 50 of Set 8 | barentu
# Processing Record 1 of Set 9 | bontang
# Processing Record 2 of Set 9 | nieuw amsterdam
# Processing Record 3 of Set 9 | saint-francois
# Processing Record 4 of Set 9 | tiznit
# Processing Record 5 of Set 9 | sorochinsk
# Processing Record 6 of Set 9 | mount gambier
# Processing Record 7 of Set 9 | port blair
# Processing Record 8 of Set 9 | puerto madero
# Processing Record 9 of Set 9 | miranorte
# City not found. Skipping...
# Processing Record 10 of Set 9 | nyuksenitsa
# Processing Record 11 of Set 9 | baherden
# Processing Record 12 of Set 9 | muros
# Processing Record 13 of Set 9 | arzachena
# Processing Record 14 of Set 9 | esperance
# Processing Record 15 of Set 9 | intipuca
# Processing Record 16 of Set 9 | harlingen
# Processing Record 17 of Set 9 | kasongo-lunda
# Processing Record 18 of Set 9 | lasa
# Processing Record 19 of Set 9 | los llanos de aridane
# Processing Record 20 of Set 9 | chicama
# Processing Record 21 of Set 9 | pokrovsk-uralskiy
# City not found. Skipping...
# Processing Record 22 of Set 9 | tenno
# Processing Record 23 of Set 9 | hit
# Processing Record 24 of Set 9 | dalbandin
# Processing Record 25 of Set 9 | peniche
# Processing Record 26 of Set 9 | kavaratti
# Processing Record 27 of Set 9 | san quintin
# Processing Record 28 of Set 9 | minab
# Processing Record 29 of Set 9 | jishou
# Processing Record 30 of Set 9 | mitsamiouli
# Processing Record 31 of Set 9 | kutum
# Processing Record 32 of Set 9 | muskogee
# Processing Record 33 of Set 9 | bilibino
# Processing Record 34 of Set 9 | luanda
# Processing Record 35 of Set 9 | manono
# Processing Record 36 of Set 9 | stephenville
# Processing Record 37 of Set 9 | ballina
# Processing Record 38 of Set 9 | conceicao do araguaia
# Processing Record 39 of Set 9 | malanje
# Processing Record 40 of Set 9 | aripuana
# Processing Record 41 of Set 9 | los lunas
# Processing Record 42 of Set 9 | fortuna
# Processing Record 43 of Set 9 | bennettsville
# Processing Record 44 of Set 9 | boyolangu
# Processing Record 45 of Set 9 | toora-khem
# Processing Record 46 of Set 9 | maple creek
# Processing Record 47 of Set 9 | washougal
# Processing Record 48 of Set 9 | kachikau
# City not found. Skipping...
# Processing Record 49 of Set 9 | kulhudhuffushi
# Processing Record 50 of Set 9 | kato khorion
# Processing Record 1 of Set 10 | husavik
# Processing Record 2 of Set 10 | tuy hoa
# Processing Record 3 of Set 10 | thunder bay
# Processing Record 4 of Set 10 | maun
# Processing Record 5 of Set 10 | pocatello
# Processing Record 6 of Set 10 | tiarei
# Processing Record 7 of Set 10 | port moresby
# Processing Record 8 of Set 10 | praesto
# Processing Record 9 of Set 10 | lulea
# Processing Record 10 of Set 10 | carutapera
# Processing Record 11 of Set 10 | ust-kuyga
# Processing Record 12 of Set 10 | bako
# Processing Record 13 of Set 10 | saint george
# Processing Record 14 of Set 10 | inta
# Processing Record 15 of Set 10 | hobyo
# Processing Record 16 of Set 10 | belle fourche
# Processing Record 17 of Set 10 | piney green
# Processing Record 18 of Set 10 | horsham
# Processing Record 19 of Set 10 | xichang
# Processing Record 20 of Set 10 | labuhan
# Processing Record 21 of Set 10 | berdigestyakh
# Processing Record 22 of Set 10 | khormuj
# City not found. Skipping...
# Processing Record 23 of Set 10 | waipawa
# Processing Record 24 of Set 10 | mirnyy
# Processing Record 25 of Set 10 | pimentel
# Processing Record 26 of Set 10 | calatayud
# Processing Record 27 of Set 10 | padrauna
# Processing Record 28 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 29 of Set 10 | sungairaya
# Processing Record 30 of Set 10 | tacuati
# Processing Record 31 of Set 10 | imeni poliny osipenko
# Processing Record 32 of Set 10 | seoul
# Processing Record 33 of Set 10 | phuntsholing
# Processing Record 34 of Set 10 | pavilosta
# Processing Record 35 of Set 10 | popondetta
# Processing Record 36 of Set 10 | ixtapa
# Processing Record 37 of Set 10 | khanpur
# Processing Record 38 of Set 10 | ust-ishim
# Processing Record 39 of Set 10 | sorland
# Processing Record 40 of Set 10 | hovd
# Processing Record 41 of Set 10 | bella vista
# Processing Record 42 of Set 10 | taltal
# Processing Record 43 of Set 10 | bacuit
# City not found. Skipping...
# Processing Record 44 of Set 10 | dunedin
# Processing Record 45 of Set 10 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 46 of Set 10 | takoradi
# Processing Record 47 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 48 of Set 10 | vitim
# Processing Record 49 of Set 10 | ozinki
# Processing Record 50 of Set 10 | maridi
# Processing Record 1 of Set 11 | cerritos
# Processing Record 2 of Set 11 | jasper
# Processing Record 3 of Set 11 | ancud
# Processing Record 4 of Set 11 | solovetskiy
# City not found. Skipping...
# Processing Record 5 of Set 11 | camacha
# Processing Record 6 of Set 11 | mangrol
# Processing Record 7 of Set 11 | iskateley
# Processing Record 8 of Set 11 | tazovskiy
# Processing Record 9 of Set 11 | iqaluit
# Processing Record 10 of Set 11 | siparia
# Processing Record 11 of Set 11 | pinehurst
# Processing Record 12 of Set 11 | zadar
# Processing Record 13 of Set 11 | mobile
# Processing Record 14 of Set 11 | praya
# Processing Record 15 of Set 11 | abu samrah
# Processing Record 16 of Set 11 | ribeira brava
# Processing Record 17 of Set 11 | maumere
# Processing Record 18 of Set 11 | demyansk
# Processing Record 19 of Set 11 | ushirombo
# Processing Record 20 of Set 11 | asekeyevo
# Processing Record 21 of Set 11 | ulaanbaatar
# Processing Record 22 of Set 11 | igarka
# Processing Record 23 of Set 11 | estevan
# Processing Record 24 of Set 11 | sitka
# Processing Record 25 of Set 11 | alihe
# Processing Record 26 of Set 11 | malwan
# City not found. Skipping...
# Processing Record 27 of Set 11 | vestmannaeyjar
# Processing Record 28 of Set 11 | sicuani
# Processing Record 29 of Set 11 | bila tserkva
# Processing Record 30 of Set 11 | san jose de pane
# City not found. Skipping...
# Processing Record 31 of Set 11 | grootfontein
# Processing Record 32 of Set 11 | benghazi
# Processing Record 33 of Set 11 | odienne
# Processing Record 34 of Set 11 | adwa
# Processing Record 35 of Set 11 | koumac
# Processing Record 36 of Set 11 | tondano
# Processing Record 37 of Set 11 | singkang
# Processing Record 38 of Set 11 | green valley
# Processing Record 39 of Set 11 | ishigaki
# Processing Record 40 of Set 11 | salzhemmendorf
# Processing Record 41 of Set 11 | makinsk
# Processing Record 42 of Set 11 | muzhi
# Processing Record 43 of Set 11 | grafton
# Processing Record 44 of Set 11 | korla
# Processing Record 45 of Set 11 | aldan
# Processing Record 46 of Set 11 | korhogo
# Processing Record 47 of Set 11 | ust-ilimsk
# Processing Record 48 of Set 11 | harper
# Processing Record 49 of Set 11 | tasiilaq
# Processing Record 50 of Set 11 | hirara
# Processing Record 1 of Set 12 | kedzierzyn-kozle
# Processing Record 2 of Set 12 | altamira
# Processing Record 3 of Set 12 | khudumelapye
# Processing Record 4 of Set 12 | emerald
# Processing Record 5 of Set 12 | oranjemund
# Processing Record 6 of Set 12 | dzhusaly
# City not found. Skipping...
# Processing Record 7 of Set 12 | aban
# Processing Record 8 of Set 12 | aitape
# Processing Record 9 of Set 12 | pevek
# Processing Record 10 of Set 12 | wattegama
# Processing Record 11 of Set 12 | charagua
# Processing Record 12 of Set 12 | skalistyy
# City not found. Skipping...
# Processing Record 13 of Set 12 | gandajika
# Processing Record 14 of Set 12 | sao filipe
# Processing Record 15 of Set 12 | grand-lahou
# Processing Record 16 of Set 12 | isla mujeres
# Processing Record 17 of Set 12 | hutang
# Processing Record 18 of Set 12 | zhaozhou
# Processing Record 19 of Set 12 | lavumisa
# Processing Record 20 of Set 12 | carbonia
# Processing Record 21 of Set 12 | harrisonville
# Processing Record 22 of Set 12 | nouadhibou
# Processing Record 23 of Set 12 | humpolec
# Processing Record 24 of Set 12 | jyvaskyla
# Processing Record 25 of Set 12 | japura
# Processing Record 26 of Set 12 | kloulklubed
# Processing Record 27 of Set 12 | bayan
# Processing Record 28 of Set 12 | lake city
# Processing Record 29 of Set 12 | carupano
# Processing Record 30 of Set 12 | clyde river
# Processing Record 31 of Set 12 | chunoyar
# Processing Record 32 of Set 12 | zeya
# Processing Record 33 of Set 12 | flinders
# Processing Record 34 of Set 12 | shieli
# Processing Record 35 of Set 12 | nizhnyaya poyma
# Processing Record 36 of Set 12 | draguignan
# Processing Record 37 of Set 12 | veisiejai
# Processing Record 38 of Set 12 | neryungri
# Processing Record 39 of Set 12 | rio grande
# Processing Record 40 of Set 12 | dolbeau
# City not found. Skipping...
# Processing Record 41 of Set 12 | alghero
# Processing Record 42 of Set 12 | onega
# Processing Record 43 of Set 12 | cibitoke
# Processing Record 44 of Set 12 | yokadouma
# Processing Record 45 of Set 12 | zemio
# Processing Record 46 of Set 12 | rafaela
# Processing Record 47 of Set 12 | nageshwari
# Processing Record 48 of Set 12 | sarakhs
# Processing Record 49 of Set 12 | alcudia
# Processing Record 50 of Set 12 | kiomboi
# Processing Record 1 of Set 13 | saint-gabriel
# Processing Record 2 of Set 13 | shasta lake
# Processing Record 3 of Set 13 | kotaparh
# Processing Record 4 of Set 13 | gidam
# Processing Record 5 of Set 13 | constitucion
# Processing Record 6 of Set 13 | barra do garcas
# Processing Record 7 of Set 13 | almeida
# Processing Record 8 of Set 13 | hede
# Processing Record 9 of Set 13 | taksimo
# Processing Record 10 of Set 13 | wuhu
# Processing Record 11 of Set 13 | fort frances
# Processing Record 12 of Set 13 | powell
# Processing Record 13 of Set 13 | montero
# Processing Record 14 of Set 13 | marsh harbour
# Processing Record 15 of Set 13 | attawapiskat
# City not found. Skipping...
# Processing Record 16 of Set 13 | deputatskiy
# Processing Record 17 of Set 13 | yefira
# City not found. Skipping...
# Processing Record 18 of Set 13 | port-cartier
# Processing Record 19 of Set 13 | mirpur mathelo
# Processing Record 20 of Set 13 | oparino
# Processing Record 21 of Set 13 | noumea
# Processing Record 22 of Set 13 | linhares
# Processing Record 23 of Set 13 | quito
# Processing Record 24 of Set 13 | mutsamudu
# City not found. Skipping...
# Processing Record 25 of Set 13 | marzuq
# Processing Record 26 of Set 13 | oktyabrskoye
# Processing Record 27 of Set 13 | halalo
# City not found. Skipping...
# Processing Record 28 of Set 13 | kemijarvi
# Processing Record 29 of Set 13 | la asuncion
# Processing Record 30 of Set 13 | cangucu
# Processing Record 31 of Set 13 | gemunden
# Processing Record 32 of Set 13 | camopi
# Processing Record 33 of Set 13 | morant bay
# Processing Record 34 of Set 13 | kon tum
# Processing Record 35 of Set 13 | bilma
# Processing Record 36 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 37 of Set 13 | george
# Processing Record 38 of Set 13 | panguna
# Processing Record 39 of Set 13 | shu
# Processing Record 40 of Set 13 | basoko
# Processing Record 41 of Set 13 | kahului
# Processing Record 42 of Set 13 | nantai
# Processing Record 43 of Set 13 | molina
# Processing Record 44 of Set 13 | terrace
# Processing Record 45 of Set 13 | gwadar
# Processing Record 46 of Set 13 | byron bay
# Processing Record 47 of Set 13 | bend
# Processing Record 48 of Set 13 | beaverlodge
# Processing Record 49 of Set 13 | ostersund
# Processing Record 50 of Set 13 | tabou
# Processing Record 1 of Set 14 | alofi
# Processing Record 2 of Set 14 | luderitz
# Processing Record 3 of Set 14 | ketchikan
# Processing Record 4 of Set 14 | gobabis
# Processing Record 5 of Set 14 | kjollefjord
# Processing Record 6 of Set 14 | matara
# Processing Record 7 of Set 14 | shirokiy
# Processing Record 8 of Set 14 | ajdabiya
# Processing Record 9 of Set 14 | vieux-habitants
# Processing Record 10 of Set 14 | scarborough
# Processing Record 11 of Set 14 | fevralsk
# City not found. Skipping...
# Processing Record 12 of Set 14 | solnechnyy
# Processing Record 13 of Set 14 | san carlos del zulia
# Processing Record 14 of Set 14 | butembo
# Processing Record 15 of Set 14 | forio
# Processing Record 16 of Set 14 | velikooktyabrskiy
# Processing Record 17 of Set 14 | nyurba
# Processing Record 18 of Set 14 | halifax
# Processing Record 19 of Set 14 | jujuy
# City not found. Skipping...
# Processing Record 20 of Set 14 | altay
# Processing Record 21 of Set 14 | piterka
# Processing Record 22 of Set 14 | hearst
# Processing Record 23 of Set 14 | baykit
# Processing Record 24 of Set 14 | qixingtai
# Processing Record 25 of Set 14 | mafinga
# Processing Record 26 of Set 14 | dwarka
# Processing Record 27 of Set 14 | palabuhanratu
# City not found. Skipping...
# Processing Record 28 of Set 14 | mercedes
# Processing Record 29 of Set 14 | acapulco
# Processing Record 30 of Set 14 | egvekinot
# Processing Record 31 of Set 14 | moose jaw
# Processing Record 32 of Set 14 | huarmey
# Processing Record 33 of Set 14 | kuche
# City not found. Skipping...
# Processing Record 34 of Set 14 | monrovia
# Processing Record 35 of Set 14 | plettenberg bay
# Processing Record 36 of Set 14 | vostok
# Processing Record 37 of Set 14 | pak phanang
# Processing Record 38 of Set 14 | manokwari
# Processing Record 39 of Set 14 | salamiyah
# Processing Record 40 of Set 14 | viedma
# Processing Record 41 of Set 14 | uvat
# Processing Record 42 of Set 14 | chiang klang
# Processing Record 43 of Set 14 | santa maria da boa vista
# Processing Record 44 of Set 14 | aberdeen
# Processing Record 45 of Set 14 | silver city
# Processing Record 46 of Set 14 | maragogi
# Processing Record 47 of Set 14 | fort morgan
# Processing Record 48 of Set 14 | visnes
# Processing Record 49 of Set 14 | nanzhang
# Processing Record 50 of Set 14 | kununurra
# Processing Record 1 of Set 15 | vilyuysk
# Processing Record 2 of Set 15 | kogon
# Processing Record 3 of Set 15 | anadyr
# Processing Record 4 of Set 15 | tiruvannamalai
# Processing Record 5 of Set 15 | agadez
# Processing Record 6 of Set 15 | mattru
# Processing Record 7 of Set 15 | hambantota
# Processing Record 8 of Set 15 | mareeba
# Processing Record 9 of Set 15 | alyangula
# Processing Record 10 of Set 15 | lovington
# Processing Record 11 of Set 15 | ardistan
# City not found. Skipping...
# Processing Record 12 of Set 15 | sur
# Processing Record 13 of Set 15 | onguday
# Processing Record 14 of Set 15 | areia branca
# Processing Record 15 of Set 15 | kampene
# Processing Record 16 of Set 15 | bara
# Processing Record 17 of Set 15 | pilar
# Processing Record 18 of Set 15 | la maddalena
# Processing Record 19 of Set 15 | mbaiki
# Processing Record 20 of Set 15 | ormara
# Processing Record 21 of Set 15 | vrangel
# Processing Record 22 of Set 15 | barao de melgaco
# Processing Record 23 of Set 15 | kem
# Processing Record 24 of Set 15 | luangwa
# Processing Record 25 of Set 15 | chardara
# Processing Record 26 of Set 15 | longlac
# City not found. Skipping...
# Processing Record 27 of Set 15 | kesennuma
# City not found. Skipping...
# Processing Record 28 of Set 15 | birin
# Processing Record 29 of Set 15 | eau claire
# Processing Record 30 of Set 15 | gushikawa
# Processing Record 31 of Set 15 | lagos
# Processing Record 32 of Set 15 | impfondo
# Processing Record 33 of Set 15 | dakar
# Processing Record 34 of Set 15 | iranshahr
# Processing Record 35 of Set 15 | stanger
# Processing Record 36 of Set 15 | sierra vista
# Processing Record 37 of Set 15 | hualmay
# Processing Record 38 of Set 15 | san rafael
# Processing Record 39 of Set 15 | rungata
# City not found. Skipping...
# Processing Record 40 of Set 15 | ugoofaaru
# Processing Record 41 of Set 15 | chingirlau
# Processing Record 42 of Set 15 | sicamous
# Processing Record 43 of Set 15 | hurghada
# Processing Record 44 of Set 15 | verkhniye sergi
# Processing Record 45 of Set 15 | baturaja
# Processing Record 46 of Set 15 | rawson
# Processing Record 47 of Set 15 | kungurtug
# Processing Record 48 of Set 15 | gardan diwal
# City not found. Skipping...
# Processing Record 49 of Set 15 | council bluffs
# Processing Record 50 of Set 15 | invermere
# Processing Record 1 of Set 16 | tra vinh
# ------------------------------
# Data Retrieval Complete
# ------------------------------

# %%
len(city_data)
# Out:
# 697

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Saskylakh      RU  71.9167  114.0833     14.00        86          93
# 1       El Vigia      VE   8.6219  -71.6506     74.82        95         100
# 2         Avarua      CK -21.2078 -159.7750     77.05        88          98
# 3        Ushtobe      KZ  45.2514   77.9838     58.60        53         100
# 4          Bluff      NZ -46.6000  168.3333     53.80        68          94
# 5        Ardakan      IR  32.3100   54.0175     83.35        14          68
# 6        Tautira      PF -17.7333 -149.1500     81.12        69          16
# 7       Kintampo      GH   8.0563   -1.7306     74.28        76         100
# 8  Alta Floresta      BR  -9.8756  -56.0861     71.58        96          50
# 9   Novopavlovka      RU  51.2172  109.2091     36.32        59         100
#
#    Wind Speed Current Description
# 0        1.68     overcast clouds
# 1        3.24     overcast clouds
# 2        1.14     overcast clouds
# 3       23.53       moderate rain
# 4       21.47     overcast clouds
# 5        4.25       broken clouds
# 6        4.45          few clouds
# 7        3.02     overcast clouds
# 8        3.29    scattered clouds
# 9        8.59     overcast clouds

# %%
# Create the output file (CSV)
output_data_file = "weather_database/WeatherPy_Database.csv"
# Export the city_data into a csv.
city_data_df.to_csv(output_data_file, index_label="City_ID")
